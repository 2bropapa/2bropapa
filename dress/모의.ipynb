# %%
import requests
import json

# 접근토큰 발급
def fn_au10001(data):
	# 1. 요청할 API URL
	host = 'https://mockapi.kiwoom.com' # 모의투자
	# host = 'https://api.kiwoom.com' # 실전투자
	endpoint = '/oauth2/token'
	url =  host + endpoint

	# 2. header 데이터
	headers = {
		'Content-Type': 'application/json;charset=UTF-8', # 컨텐츠타입
	}

	# 3. http POST 요청
	response = requests.post(url, headers=headers, json=data)

	# 4. 응답 상태 코드와 데이터 출력
	print('Code:', response.status_code)
	print('Header:', json.dumps({key: response.headers.get(key) for key in ['next-key', 'cont-yn', 'api-id']}, indent=4, ensure_ascii=False))
	print('Body:', json.dumps(response.json(), indent=4, ensure_ascii=False))  # JSON 응답을 파싱하여 출력

# 실행 구간
if __name__ == '__main__':
	# 1. 요청 데이터
	params = {
		'grant_type': 'client_credentials',  # grant_type
		'appkey': '7iS25965g6sXqK8m9SRB0sCUvVFpyVsfsi4mIgt0Bkw',  # 앱키
		'secretkey': 'Az6h02M_7Unsk7DqCxbs9a0Bnit9rCwUWDZd6_wiBx8',  # 시크릿키
	}

	# 2. API 실행
	fn_au10001(data=params)
# Out:
# Code: 200
# Header: {
#     "next-key": null,
#     "cont-yn": null,
#     "api-id": null
# }
# Body: {
#     "expires_dt": "20250416150608",
#     "return_msg": "정상적으로 처리되었습니다",
#     "token_type": "Bearer",
#     "return_code": 0,
#     "token": "BFEQZhMt8cgEKVy1Qj2beKI9YMik1wXvfxj0RV8X_TN84hL1kF-r5ZKXovUXSSpM3NK0gkwaTTX_AinxL2E_Bg"
# }

# %%
import requests
import json

# 당일거래량상위요청
def fn_ka10030(token, data, cont_yn='N', next_key=''):
	# 1. 요청할 API URL
	host = 'https://mockapi.kiwoom.com' # 모의투자
	# host = 'https://api.kiwoom.com' # 실전투자
	endpoint = '/api/dostk/rkinfo'
	url =  host + endpoint

	# 2. header 데이터
	headers = {
		'Content-Type': 'application/json;charset=UTF-8', # 컨텐츠타입
		'authorization': f'Bearer {token}', # 접근토큰
		'cont-yn': cont_yn, # 연속조회여부
		'next-key': next_key, # 연속조회키
		'api-id': 'ka10030', # TR명
	}

	# 3. http POST 요청
	response = requests.post(url, headers=headers, json=data)

	# 4. 응답 상태 코드와 데이터 출력
	print('Code:', response.status_code)
	print('Header:', json.dumps({key: response.headers.get(key) for key in ['next-key', 'cont-yn', 'api-id']}, indent=4, ensure_ascii=False))
	print('Body:', json.dumps(response.json(), indent=4, ensure_ascii=False))  # JSON 응답을 파싱하여 출력

# 실행 구간
if __name__ == '__main__':
	# 1. 토큰 설정
	MY_ACCESS_TOKEN = 'BFEQZhMt8cgEKVy1Qj2beKI9YMik1wXvfxj0RV8X_TN84hL1kF-r5ZKXovUXSSpM3NK0gkwaTTX_AinxL2E_Bg'# 접근토큰

	# 2. 요청 데이터
	params = {
		'mrkt_tp': '000', # 시장구분 000:전체, 001:코스피, 101:코스닥
		'sort_tp': '1', # 정렬구분 1:거래량, 2:거래회전율, 3:거래대금
		'mang_stk_incls': '0', # 관리종목포함 0:관리종목 포함, 1:관리종목 미포함, 3:우선주제외, 11:정리매매종목제외, 4:관리종목, 우선주제외, 5:증100제외, 6:증100마나보기, 13:증60만보기, 12:증50만보기, 7:증40만보기, 8:증30만보기, 9:증20만보기, 14:ETF제외, 15:스팩제외, 16:ETF+ETN제외
		'crd_tp': '0', # 신용구분 0:전체조회, 9:신용융자전체, 1:신용융자A군, 2:신용융자B군, 3:신용융자C군, 4:신용융자D군, 8:신용대주
		'trde_qty_tp': '0', # 거래량구분 0:전체조회, 5:5천주이상, 10:1만주이상, 50:5만주이상, 100:10만주이상, 200:20만주이상, 300:30만주이상, 500:500만주이상, 1000:백만주이상
		'pric_tp': '0', # 가격구분 0:전체조회, 1:1천원미만, 2:1천원이상, 3:1천원~2천원, 4:2천원~5천원, 5:5천원이상, 6:5천원~1만원, 10:1만원미만, 7:1만원이상, 8:5만원이상, 9:10만원이상
		'trde_prica_tp': '0', # 거래대금구분 0:전체조회, 1:1천만원이상, 3:3천만원이상, 4:5천만원이상, 10:1억원이상, 30:3억원이상, 50:5억원이상, 100:10억원이상, 300:30억원이상, 500:50억원이상, 1000:100억원이상, 3000:300억원이상, 5000:500억원이상
		'mrkt_open_tp': '0', # 장운영구분 0:전체조회, 1:장중, 2:장전시간외, 3:장후시간외
		'stex_tp': '3', # 거래소구분 1:KRX, 2:NXT 3.통합
	}

	# 3. API 실행
	fn_ka10030(token=MY_ACCESS_TOKEN, data=params)

	# next-key, cont-yn 값이 있을 경우
	# fn_ka10030(token=MY_ACCESS_TOKEN, data=params, cont_yn='N', next_key='nextkey..')
# Out:
# Code: 200
# Header: {
#     "next-key": "000100000000000000001",
#     "cont-yn": "Y",
#     "api-id": "ka10030"
# }
# Body: {
#     "tdy_trde_qty_upper": [
#         {
#             "stk_cd": "008970_AL",
#             "stk_nm": "동양철관",
#             "cur_prc": "+1665",
#             "pred_pre_sig": "2",
#             "pred_pre": "+90",
#             "flu_rt": "+5.71",
#             "trde_qty": "167863209",
#             "pred_rt": "+113.51",
#             "trde_tern_rt": "+105.77",
#             "trde_amt": "283053",
#             "opmr_trde_qty": "167632883",
#             "opmr_pred_rt": "+120.97",
#             "opmr_trde_rt": "+105.63",
#             "opmr_trde_amt": "282670",
#             "af_mkrt_trde_qty": "230320",
#             "af_mkrt_pred_rt": "-25.10",
#             "af_mkrt_trde_rt": "+0.15",
#             "af_mkrt_trde_amt": "383",
#             "bf_mkrt_trde_qty": "6",
#             "bf_mkrt_pred_rt": "-0.05",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "252670_AL",
#             "stk_nm": "KODEX 200선물인버스2X",
#             "cur_prc": "-2305",
#             "pred_pre_sig": "5",
#             "pred_pre": "-45",
#             "flu_rt": "-1.91",
#             "trde_qty": "98233927",
#             "pred_rt": "+108.34",
#             "trde_tern_rt": "+22.19",
#             "trde_amt": "227498",
#             "opmr_trde_qty": "97921877",
#             "opmr_pred_rt": "+109.80",
#             "opmr_trde_rt": "+22.12",
#             "opmr_trde_amt": "226773",
#             "af_mkrt_trde_qty": "170101",
#             "af_mkrt_pred_rt": "-34.44",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "392",
#             "bf_mkrt_trde_qty": "141949",
#             "bf_mkrt_pred_rt": "+151.18",
#             "bf_mkrt_trde_rt": "+0.04",
#             "bf_mkrt_trde_amt": "334"
#         },
#         {
#             "stk_cd": "090710_AL",
#             "stk_nm": "휴림로봇",
#             "cur_prc": "+2145",
#             "pred_pre_sig": "2",
#             "pred_pre": "+217",
#             "flu_rt": "+11.26",
#             "trde_qty": "41652099",
#             "pred_rt": "+761.32",
#             "trde_tern_rt": "+37.78",
#             "trde_amt": "90383",
#             "opmr_trde_qty": "41612741",
#             "opmr_pred_rt": "+766.08",
#             "opmr_trde_rt": "+37.75",
#             "opmr_trde_amt": "90299",
#             "af_mkrt_trde_qty": "37917",
#             "af_mkrt_pred_rt": "+839.99",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "81",
#             "bf_mkrt_trde_qty": "1441",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "3"
#         },
#         {
#             "stk_cd": "011420_AL",
#             "stk_nm": "갤럭시아에스엠",
#             "cur_prc": "+2555",
#             "pred_pre_sig": "2",
#             "pred_pre": "+400",
#             "flu_rt": "+18.56",
#             "trde_qty": "35900861",
#             "pred_rt": "+6700.40",
#             "trde_tern_rt": "+130.31",
#             "trde_amt": "92021",
#             "opmr_trde_qty": "35877531",
#             "opmr_pred_rt": "+6783.66",
#             "opmr_trde_rt": "+130.23",
#             "opmr_trde_amt": "91962",
#             "af_mkrt_trde_qty": "22030",
#             "af_mkrt_pred_rt": "+1982.90",
#             "af_mkrt_trde_rt": "+0.08",
#             "af_mkrt_trde_amt": "56",
#             "bf_mkrt_trde_qty": "1300",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "3"
#         },
#         {
#             "stk_cd": "457600_AL",
#             "stk_nm": "벡트",
#             "cur_prc": "+5820",
#             "pred_pre_sig": "2",
#             "pred_pre": "+985",
#             "flu_rt": "+20.37",
#             "trde_qty": "34202277",
#             "pred_rt": "+1130.49",
#             "trde_tern_rt": "+249.52",
#             "trde_amt": "195361",
#             "opmr_trde_qty": "34179689",
#             "opmr_pred_rt": "+1151.69",
#             "opmr_trde_rt": "+249.36",
#             "opmr_trde_amt": "195230",
#             "af_mkrt_trde_qty": "22219",
#             "af_mkrt_pred_rt": "+165.49",
#             "af_mkrt_trde_rt": "+0.17",
#             "af_mkrt_trde_amt": "129",
#             "bf_mkrt_trde_qty": "369",
#             "bf_mkrt_pred_rt": "-22.28",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "251340_AL",
#             "stk_nm": "KODEX 코스닥150선물인버스",
#             "cur_prc": "3960",
#             "pred_pre_sig": "3",
#             "pred_pre": "0",
#             "flu_rt": "0.00",
#             "trde_qty": "32740693",
#             "pred_rt": "+110.77",
#             "trde_tern_rt": "+55.12",
#             "trde_amt": "130281",
#             "opmr_trde_qty": "32574975",
#             "opmr_pred_rt": "+112.50",
#             "opmr_trde_rt": "+54.85",
#             "opmr_trde_amt": "129625",
#             "af_mkrt_trde_qty": "124620",
#             "af_mkrt_pred_rt": "+236.78",
#             "af_mkrt_trde_rt": "+0.21",
#             "af_mkrt_trde_amt": "493",
#             "bf_mkrt_trde_qty": "41098",
#             "bf_mkrt_pred_rt": "+118.53",
#             "bf_mkrt_trde_rt": "+0.07",
#             "bf_mkrt_trde_amt": "163"
#         },
#         {
#             "stk_cd": "246690_AL",
#             "stk_nm": "TS인베스트먼트",
#             "cur_prc": "-1917",
#             "pred_pre_sig": "5",
#             "pred_pre": "-13",
#             "flu_rt": "-0.67",
#             "trde_qty": "31598201",
#             "pred_rt": "+155.78",
#             "trde_tern_rt": "+76.18",
#             "trde_amt": "66622",
#             "opmr_trde_qty": "31593261",
#             "opmr_pred_rt": "+155.80",
#             "opmr_trde_rt": "+76.17",
#             "opmr_trde_amt": "66613",
#             "af_mkrt_trde_qty": "4940",
#             "af_mkrt_pred_rt": "+1625.01",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "9",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "071090_AL",
#             "stk_nm": "하이스틸",
#             "cur_prc": "+5130",
#             "pred_pre_sig": "1",
#             "pred_pre": "+1180",
#             "flu_rt": "+29.87",
#             "trde_qty": "30627993",
#             "pred_rt": "+920.16",
#             "trde_tern_rt": "+151.69",
#             "trde_amt": "151553",
#             "opmr_trde_qty": "30626053",
#             "opmr_pred_rt": "+1108.42",
#             "opmr_trde_rt": "+151.68",
#             "opmr_trde_amt": "151543",
#             "af_mkrt_trde_qty": "1940",
#             "af_mkrt_pred_rt": "-6.19",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "10",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "241520_AL",
#             "stk_nm": "DSC인베스트먼트",
#             "cur_prc": "-8390",
#             "pred_pre_sig": "5",
#             "pred_pre": "-20",
#             "flu_rt": "-0.24",
#             "trde_qty": "25705745",
#             "pred_rt": "+742.67",
#             "trde_tern_rt": "+93.49",
#             "trde_amt": "236748",
#             "opmr_trde_qty": "25696233",
#             "opmr_pred_rt": "+743.61",
#             "opmr_trde_rt": "+93.46",
#             "opmr_trde_amt": "236668",
#             "af_mkrt_trde_qty": "9512",
#             "af_mkrt_pred_rt": "+45295.25",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "80",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "233740_AL",
#             "stk_nm": "KODEX 코스닥150레버리지",
#             "cur_prc": "+6925",
#             "pred_pre_sig": "2",
#             "pred_pre": "+5",
#             "flu_rt": "+0.07",
#             "trde_qty": "25641623",
#             "pred_rt": "-81.56",
#             "trde_tern_rt": "+8.54",
#             "trde_amt": "176180",
#             "opmr_trde_qty": "25600698",
#             "opmr_pred_rt": "-82.48",
#             "opmr_trde_rt": "+8.53",
#             "opmr_trde_amt": "175896",
#             "af_mkrt_trde_qty": "19647",
#             "af_mkrt_pred_rt": "-74.03",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "136",
#             "bf_mkrt_trde_qty": "21278",
#             "bf_mkrt_pred_rt": "+2127800.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "147"
#         },
#         {
#             "stk_cd": "092790_AL",
#             "stk_nm": "넥스틸",
#             "cur_prc": "+16750",
#             "pred_pre_sig": "2",
#             "pred_pre": "+1450",
#             "flu_rt": "+9.48",
#             "trde_qty": "21166611",
#             "pred_rt": "+299.49",
#             "trde_tern_rt": "+81.40",
#             "trde_amt": "367030",
#             "opmr_trde_qty": "21165375",
#             "opmr_pred_rt": "+299.86",
#             "opmr_trde_rt": "+81.40",
#             "opmr_trde_amt": "367010",
#             "af_mkrt_trde_qty": "622",
#             "af_mkrt_pred_rt": "-7.15",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "10",
#             "bf_mkrt_trde_qty": "614",
#             "bf_mkrt_pred_rt": "+244.63",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "9"
#         },
#         {
#             "stk_cd": "004140_AL",
#             "stk_nm": "동방",
#             "cur_prc": "+2600",
#             "pred_pre_sig": "2",
#             "pred_pre": "+340",
#             "flu_rt": "+15.04",
#             "trde_qty": "19438578",
#             "pred_rt": "+2367.18",
#             "trde_tern_rt": "+40.52",
#             "trde_amt": "50235",
#             "opmr_trde_qty": "19423155",
#             "opmr_pred_rt": "+2400.04",
#             "opmr_trde_rt": "+40.49",
#             "opmr_trde_amt": "50194",
#             "af_mkrt_trde_qty": "15423",
#             "af_mkrt_pred_rt": "+236.84",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "40",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "093240_AL",
#             "stk_nm": "형지엘리트",
#             "cur_prc": "+3115",
#             "pred_pre_sig": "2",
#             "pred_pre": "+395",
#             "flu_rt": "+14.52",
#             "trde_qty": "18754035",
#             "pred_rt": "+1378.21",
#             "trde_tern_rt": "+48.85",
#             "trde_amt": "60333",
#             "opmr_trde_qty": "18747168",
#             "opmr_pred_rt": "+1395.60",
#             "opmr_trde_rt": "+48.84",
#             "opmr_trde_amt": "60311",
#             "af_mkrt_trde_qty": "6424",
#             "af_mkrt_pred_rt": "+410.22",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "20",
#             "bf_mkrt_trde_qty": "443",
#             "bf_mkrt_pred_rt": "-44.29",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "1"
#         },
#         {
#             "stk_cd": "215100_AL",
#             "stk_nm": "로보로보",
#             "cur_prc": "+5070",
#             "pred_pre_sig": "2",
#             "pred_pre": "+790",
#             "flu_rt": "+18.46",
#             "trde_qty": "18178640",
#             "pred_rt": "+226.31",
#             "trde_tern_rt": "+89.34",
#             "trde_amt": "91785",
#             "opmr_trde_qty": "18169521",
#             "opmr_pred_rt": "+227.65",
#             "opmr_trde_rt": "+89.30",
#             "opmr_trde_amt": "91739",
#             "af_mkrt_trde_qty": "9119",
#             "af_mkrt_pred_rt": "+148.19",
#             "af_mkrt_trde_rt": "+0.05",
#             "af_mkrt_trde_amt": "46",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "122630_AL",
#             "stk_nm": "KODEX 레버리지",
#             "cur_prc": "+14635",
#             "pred_pre_sig": "2",
#             "pred_pre": "+265",
#             "flu_rt": "+1.84",
#             "trde_qty": "17513156",
#             "pred_rt": "-85.59",
#             "trde_tern_rt": "+9.43",
#             "trde_amt": "255439",
#             "opmr_trde_qty": "17461608",
#             "opmr_pred_rt": "-86.40",
#             "opmr_trde_rt": "+9.41",
#             "opmr_trde_amt": "254694",
#             "af_mkrt_trde_qty": "15203",
#             "af_mkrt_pred_rt": "-47.38",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "222",
#             "bf_mkrt_trde_qty": "36345",
#             "bf_mkrt_pred_rt": "+46006.34",
#             "bf_mkrt_trde_rt": "+0.02",
#             "bf_mkrt_trde_amt": "522"
#         },
#         {
#             "stk_cd": "094480_AL",
#             "stk_nm": "갤럭시아머니트리",
#             "cur_prc": "-8200",
#             "pred_pre_sig": "5",
#             "pred_pre": "-200",
#             "flu_rt": "-2.38",
#             "trde_qty": "16716585",
#             "pred_rt": "+2118.86",
#             "trde_tern_rt": "+42.61",
#             "trde_amt": "149007",
#             "opmr_trde_qty": "16715395",
#             "opmr_pred_rt": "+2119.57",
#             "opmr_trde_rt": "+42.61",
#             "opmr_trde_amt": "148997",
#             "af_mkrt_trde_qty": "1190",
#             "af_mkrt_pred_rt": "+373.05",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "10",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "389680_AL",
#             "stk_nm": "유디엠텍",
#             "cur_prc": "-837",
#             "pred_pre_sig": "5",
#             "pred_pre": "-44",
#             "flu_rt": "-4.99",
#             "trde_qty": "15861125",
#             "pred_rt": "-96.71",
#             "trde_tern_rt": "+39.64",
#             "trde_amt": "13595",
#             "opmr_trde_qty": "15836201",
#             "opmr_pred_rt": "-96.66",
#             "opmr_trde_rt": "+39.58",
#             "opmr_trde_amt": "13574",
#             "af_mkrt_trde_qty": "24924",
#             "af_mkrt_pred_rt": "+146.53",
#             "af_mkrt_trde_rt": "+0.07",
#             "af_mkrt_trde_amt": "21",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "005010_AL",
#             "stk_nm": "휴스틸",
#             "cur_prc": "+5580",
#             "pred_pre_sig": "2",
#             "pred_pre": "+270",
#             "flu_rt": "+5.08",
#             "trde_qty": "15255837",
#             "pred_rt": "+463.24",
#             "trde_tern_rt": "+27.15",
#             "trde_amt": "87511",
#             "opmr_trde_qty": "15254217",
#             "opmr_pred_rt": "+465.94",
#             "opmr_trde_rt": "+27.15",
#             "opmr_trde_amt": "87502",
#             "af_mkrt_trde_qty": "1120",
#             "af_mkrt_pred_rt": "-5.78",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "6",
#             "bf_mkrt_trde_qty": "500",
#             "bf_mkrt_pred_rt": "+1219.52",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "3"
#         },
#         {
#             "stk_cd": "043910_AL",
#             "stk_nm": "자연과환경",
#             "cur_prc": "-910",
#             "pred_pre_sig": "5",
#             "pred_pre": "-24",
#             "flu_rt": "-2.57",
#             "trde_qty": "14870298",
#             "pred_rt": "+100.69",
#             "trde_tern_rt": "+13.11",
#             "trde_amt": "13814",
#             "opmr_trde_qty": "14859247",
#             "opmr_pred_rt": "+103.15",
#             "opmr_trde_rt": "+13.11",
#             "opmr_trde_amt": "13804",
#             "af_mkrt_trde_qty": "10701",
#             "af_mkrt_pred_rt": "-32.19",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "10",
#             "bf_mkrt_trde_qty": "350",
#             "bf_mkrt_pred_rt": "-68.49",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "900110_AL",
#             "stk_nm": "이스트아시아홀딩스",
#             "cur_prc": "50",
#             "pred_pre_sig": "3",
#             "pred_pre": "0",
#             "flu_rt": "0.00",
#             "trde_qty": "14838007",
#             "pred_rt": "-29.10",
#             "trde_tern_rt": "+2.31",
#             "trde_amt": "730",
#             "opmr_trde_qty": "14600805",
#             "opmr_pred_rt": "-29.12",
#             "opmr_trde_rt": "+2.28",
#             "opmr_trde_amt": "718",
#             "af_mkrt_trde_qty": "237197",
#             "af_mkrt_pred_rt": "+278.27",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "12",
#             "bf_mkrt_trde_qty": "5",
#             "bf_mkrt_pred_rt": "+500.01",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "114800_AL",
#             "stk_nm": "KODEX 인버스",
#             "cur_prc": "-4590",
#             "pred_pre_sig": "5",
#             "pred_pre": "-45",
#             "flu_rt": "-0.97",
#             "trde_qty": "14052886",
#             "pred_rt": "+120.36",
#             "trde_tern_rt": "+12.95",
#             "trde_amt": "64622",
#             "opmr_trde_qty": "13955714",
#             "opmr_pred_rt": "+121.00",
#             "opmr_trde_rt": "+12.87",
#             "opmr_trde_amt": "64174",
#             "af_mkrt_trde_qty": "53601",
#             "af_mkrt_pred_rt": "+774.81",
#             "af_mkrt_trde_rt": "+0.05",
#             "af_mkrt_trde_amt": "246",
#             "bf_mkrt_trde_qty": "43571",
#             "bf_mkrt_pred_rt": "+8714.21",
#             "bf_mkrt_trde_rt": "+0.05",
#             "bf_mkrt_trde_amt": "202"
#         },
#         {
#             "stk_cd": "002630_AL",
#             "stk_nm": "오리엔트바이오",
#             "cur_prc": "+1922",
#             "pred_pre_sig": "2",
#             "pred_pre": "+56",
#             "flu_rt": "+3.00",
#             "trde_qty": "13299055",
#             "pred_rt": "+133.09",
#             "trde_tern_rt": "+11.21",
#             "trde_amt": "25971",
#             "opmr_trde_qty": "13290504",
#             "opmr_pred_rt": "+134.15",
#             "opmr_trde_rt": "+11.21",
#             "opmr_trde_amt": "25954",
#             "af_mkrt_trde_qty": "7415",
#             "af_mkrt_pred_rt": "+168.99",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "14",
#             "bf_mkrt_trde_qty": "1136",
#             "bf_mkrt_pred_rt": "+309.54",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "462330_AL",
#             "stk_nm": "KODEX 2차전지산업레버리지",
#             "cur_prc": "928",
#             "pred_pre_sig": "3",
#             "pred_pre": "0",
#             "flu_rt": "0.00",
#             "trde_qty": "12988646",
#             "pred_rt": "-93.53",
#             "trde_tern_rt": "+6.08",
#             "trde_amt": "12037",
#             "opmr_trde_qty": "12987340",
#             "opmr_pred_rt": "-94.27",
#             "opmr_trde_rt": "+6.09",
#             "opmr_trde_amt": "12036",
#             "af_mkrt_trde_qty": "1306",
#             "af_mkrt_pred_rt": "0.00",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "1",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "051980_AL",
#             "stk_nm": "중앙첨단소재",
#             "cur_prc": "+5300",
#             "pred_pre_sig": "2",
#             "pred_pre": "+970",
#             "flu_rt": "+22.40",
#             "trde_qty": "11542850",
#             "pred_rt": "+235.52",
#             "trde_tern_rt": "+11.34",
#             "trde_amt": "58922",
#             "opmr_trde_qty": "11541531",
#             "opmr_pred_rt": "+235.52",
#             "opmr_trde_rt": "+11.34",
#             "opmr_trde_amt": "58915",
#             "af_mkrt_trde_qty": "1319",
#             "af_mkrt_pred_rt": "+362.37",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "7",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "048470_AL",
#             "stk_nm": "대동스틸",
#             "cur_prc": "+5680",
#             "pred_pre_sig": "2",
#             "pred_pre": "+980",
#             "flu_rt": "+20.85",
#             "trde_qty": "11533612",
#             "pred_rt": "+971.79",
#             "trde_tern_rt": "+115.34",
#             "trde_amt": "65076",
#             "opmr_trde_qty": "11524850",
#             "opmr_pred_rt": "+1426.01",
#             "opmr_trde_rt": "+115.25",
#             "opmr_trde_amt": "65026",
#             "af_mkrt_trde_qty": "8762",
#             "af_mkrt_pred_rt": "+119.66",
#             "af_mkrt_trde_rt": "+0.09",
#             "af_mkrt_trde_amt": "50",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "005930_AL",
#             "stk_nm": "삼성전자",
#             "cur_prc": "+56800",
#             "pred_pre_sig": "2",
#             "pred_pre": "+600",
#             "flu_rt": "+1.07",
#             "trde_qty": "11117510",
#             "pred_rt": "-63.45",
#             "trde_tern_rt": "+0.19",
#             "trde_amt": "630425",
#             "opmr_trde_qty": "11115007",
#             "opmr_pred_rt": "-65.10",
#             "opmr_trde_rt": "+0.19",
#             "opmr_trde_amt": "630284",
#             "af_mkrt_trde_qty": "1984",
#             "af_mkrt_pred_rt": "-0.44",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "112",
#             "bf_mkrt_trde_qty": "519",
#             "bf_mkrt_pred_rt": "+5190.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "29"
#         },
#         {
#             "stk_cd": "090080_AL",
#             "stk_nm": "평화산업",
#             "cur_prc": "-1826",
#             "pred_pre_sig": "5",
#             "pred_pre": "-124",
#             "flu_rt": "-6.36",
#             "trde_qty": "10904092",
#             "pred_rt": "-41.52",
#             "trde_tern_rt": "+19.86",
#             "trde_amt": "20470",
#             "opmr_trde_qty": "10893708",
#             "opmr_pred_rt": "-41.50",
#             "opmr_trde_rt": "+19.85",
#             "opmr_trde_amt": "20451",
#             "af_mkrt_trde_qty": "10378",
#             "af_mkrt_pred_rt": "+337.72",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "19",
#             "bf_mkrt_trde_qty": "6",
#             "bf_mkrt_pred_rt": "-0.09",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "131370_AL",
#             "stk_nm": "알서포트",
#             "cur_prc": "+3900",
#             "pred_pre_sig": "2",
#             "pred_pre": "+285",
#             "flu_rt": "+7.88",
#             "trde_qty": "10390937",
#             "pred_rt": "+508.38",
#             "trde_tern_rt": "+19.51",
#             "trde_amt": "41572",
#             "opmr_trde_qty": "10382015",
#             "opmr_pred_rt": "+512.40",
#             "opmr_trde_rt": "+19.50",
#             "opmr_trde_amt": "41538",
#             "af_mkrt_trde_qty": "4251",
#             "af_mkrt_pred_rt": "+524.17",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "17",
#             "bf_mkrt_trde_qty": "4671",
#             "bf_mkrt_pred_rt": "+295.83",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "17"
#         },
#         {
#             "stk_cd": "448900_AL",
#             "stk_nm": "한국피아이엠",
#             "cur_prc": "+18690",
#             "pred_pre_sig": "1",
#             "pred_pre": "+4310",
#             "flu_rt": "+29.97",
#             "trde_qty": "9984182",
#             "pred_rt": "+723.51",
#             "trde_tern_rt": "+166.28",
#             "trde_amt": "170724",
#             "opmr_trde_qty": "9983968",
#             "opmr_pred_rt": "+819.44",
#             "opmr_trde_rt": "+166.28",
#             "opmr_trde_amt": "170720",
#             "af_mkrt_trde_qty": "207",
#             "af_mkrt_pred_rt": "+125.46",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "4",
#             "bf_mkrt_trde_qty": "7",
#             "bf_mkrt_pred_rt": "-0.52",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "484810_AL",
#             "stk_nm": "티엑스알로보틱스",
#             "cur_prc": "+21750",
#             "pred_pre_sig": "2",
#             "pred_pre": "+3220",
#             "flu_rt": "+17.38",
#             "trde_qty": "9761456",
#             "pred_rt": "+1627.91",
#             "trde_tern_rt": "+63.18",
#             "trde_amt": "210262",
#             "opmr_trde_qty": "9756566",
#             "opmr_pred_rt": "+1708.20",
#             "opmr_trde_rt": "+63.15",
#             "opmr_trde_amt": "210157",
#             "af_mkrt_trde_qty": "4247",
#             "af_mkrt_pred_rt": "+241.04",
#             "af_mkrt_trde_rt": "+0.03",
#             "af_mkrt_trde_amt": "92",
#             "bf_mkrt_trde_qty": "643",
#             "bf_mkrt_pred_rt": "-62.48",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "12"
#         },
#         {
#             "stk_cd": "315640_AL",
#             "stk_nm": "딥노이드",
#             "cur_prc": "+7440",
#             "pred_pre_sig": "2",
#             "pred_pre": "+1240",
#             "flu_rt": "+20.00",
#             "trde_qty": "8957017",
#             "pred_rt": "+2553.18",
#             "trde_tern_rt": "+39.95",
#             "trde_amt": "66632",
#             "opmr_trde_qty": "8955698",
#             "opmr_pred_rt": "+2552.81",
#             "opmr_trde_rt": "+39.95",
#             "opmr_trde_amt": "66623",
#             "af_mkrt_trde_qty": "1319",
#             "af_mkrt_pred_rt": "0.00",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "10",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "475460_AL",
#             "stk_nm": "미트박스",
#             "cur_prc": "+15800",
#             "pred_pre_sig": "2",
#             "pred_pre": "+2930",
#             "flu_rt": "+22.77",
#             "trde_qty": "8803565",
#             "pred_rt": "+1509.71",
#             "trde_tern_rt": "+157.57",
#             "trde_amt": "128651",
#             "opmr_trde_qty": "8788259",
#             "opmr_pred_rt": "+1548.70",
#             "opmr_trde_rt": "+157.30",
#             "opmr_trde_amt": "128410",
#             "af_mkrt_trde_qty": "15306",
#             "af_mkrt_pred_rt": "+5446.98",
#             "af_mkrt_trde_rt": "+0.28",
#             "af_mkrt_trde_amt": "242",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "017510_AL",
#             "stk_nm": "세명전기",
#             "cur_prc": "+6390",
#             "pred_pre_sig": "2",
#             "pred_pre": "+260",
#             "flu_rt": "+4.24",
#             "trde_qty": "8548154",
#             "pred_rt": "+439.41",
#             "trde_tern_rt": "+56.07",
#             "trde_amt": "55591",
#             "opmr_trde_qty": "8539361",
#             "opmr_pred_rt": "+446.80",
#             "opmr_trde_rt": "+56.02",
#             "opmr_trde_amt": "55535",
#             "af_mkrt_trde_qty": "8581",
#             "af_mkrt_pred_rt": "+564.54",
#             "af_mkrt_trde_rt": "+0.06",
#             "af_mkrt_trde_amt": "55",
#             "bf_mkrt_trde_qty": "212",
#             "bf_mkrt_pred_rt": "-87.96",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "1"
#         },
#         {
#             "stk_cd": "065500_AL",
#             "stk_nm": "오리엔트정공",
#             "cur_prc": "+13990",
#             "pred_pre_sig": "2",
#             "pred_pre": "+820",
#             "flu_rt": "+6.23",
#             "trde_qty": "8017224",
#             "pred_rt": "+149.56",
#             "trde_tern_rt": "+25.26",
#             "trde_amt": "112342",
#             "opmr_trde_qty": "8008402",
#             "opmr_pred_rt": "+150.61",
#             "opmr_trde_rt": "+25.23",
#             "opmr_trde_amt": "112221",
#             "af_mkrt_trde_qty": "5886",
#             "af_mkrt_pred_rt": "-89.33",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "82",
#             "bf_mkrt_trde_qty": "2936",
#             "bf_mkrt_pred_rt": "+179.69",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "39"
#         },
#         {
#             "stk_cd": "054300_AL",
#             "stk_nm": "팬스타엔터프라이즈",
#             "cur_prc": "-591",
#             "pred_pre_sig": "5",
#             "pred_pre": "-96",
#             "flu_rt": "-13.97",
#             "trde_qty": "8012271",
#             "pred_rt": "-38.43",
#             "trde_tern_rt": "+11.96",
#             "trde_amt": "4917",
#             "opmr_trde_qty": "7997717",
#             "opmr_pred_rt": "-38.37",
#             "opmr_trde_rt": "+11.94",
#             "opmr_trde_amt": "4908",
#             "af_mkrt_trde_qty": "14554",
#             "af_mkrt_pred_rt": "+90962.50",
#             "af_mkrt_trde_rt": "+0.03",
#             "af_mkrt_trde_amt": "9",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "239340_AL",
#             "stk_nm": "이스트에이드",
#             "cur_prc": "-2630",
#             "pred_pre_sig": "5",
#             "pred_pre": "-330",
#             "flu_rt": "-11.15",
#             "trde_qty": "7871875",
#             "pred_rt": "+654.15",
#             "trde_tern_rt": "+29.18",
#             "trde_amt": "24149",
#             "opmr_trde_qty": "7866327",
#             "opmr_pred_rt": "+654.43",
#             "opmr_trde_rt": "+29.16",
#             "opmr_trde_amt": "24134",
#             "af_mkrt_trde_qty": "5547",
#             "af_mkrt_pred_rt": "+777.99",
#             "af_mkrt_trde_rt": "+0.03",
#             "af_mkrt_trde_amt": "15",
#             "bf_mkrt_trde_qty": "1",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "274090_AL",
#             "stk_nm": "켄코아에어로스페이스",
#             "cur_prc": "+12330",
#             "pred_pre_sig": "2",
#             "pred_pre": "+1160",
#             "flu_rt": "+10.38",
#             "trde_qty": "7758343",
#             "pred_rt": "+3557.21",
#             "trde_tern_rt": "+59.20",
#             "trde_amt": "100144",
#             "opmr_trde_qty": "7757010",
#             "opmr_pred_rt": "+3557.37",
#             "opmr_trde_rt": "+59.20",
#             "opmr_trde_amt": "100128",
#             "af_mkrt_trde_qty": "1332",
#             "af_mkrt_pred_rt": "+2895.66",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "17",
#             "bf_mkrt_trde_qty": "1",
#             "bf_mkrt_pred_rt": "+100.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "293580_AL",
#             "stk_nm": "나우IB",
#             "cur_prc": "-1338",
#             "pred_pre_sig": "5",
#             "pred_pre": "-28",
#             "flu_rt": "-2.05",
#             "trde_qty": "7742287",
#             "pred_rt": "-20.46",
#             "trde_tern_rt": "+8.16",
#             "trde_amt": "10223",
#             "opmr_trde_qty": "7720625",
#             "opmr_pred_rt": "-20.58",
#             "opmr_trde_rt": "+8.14",
#             "opmr_trde_amt": "10194",
#             "af_mkrt_trde_qty": "12398",
#             "af_mkrt_pred_rt": "+246.14",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "17",
#             "bf_mkrt_trde_qty": "9264",
#             "bf_mkrt_pred_rt": "+1366.38",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "13"
#         },
#         {
#             "stk_cd": "193250_AL",
#             "stk_nm": "링크드",
#             "cur_prc": "-723",
#             "pred_pre_sig": "5",
#             "pred_pre": "-132",
#             "flu_rt": "-15.44",
#             "trde_qty": "7235613",
#             "pred_rt": "-30.02",
#             "trde_tern_rt": "+11.43",
#             "trde_amt": "5381",
#             "opmr_trde_qty": "7231497",
#             "opmr_pred_rt": "-30.26",
#             "opmr_trde_rt": "+11.42",
#             "opmr_trde_amt": "5378",
#             "af_mkrt_trde_qty": "4099",
#             "af_mkrt_pred_rt": "-31.52",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "3",
#             "bf_mkrt_trde_qty": "17",
#             "bf_mkrt_pred_rt": "-0.17",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "014160_AL",
#             "stk_nm": "대영포장",
#             "cur_prc": "-1828",
#             "pred_pre_sig": "5",
#             "pred_pre": "-136",
#             "flu_rt": "-6.92",
#             "trde_qty": "7216360",
#             "pred_rt": "-28.13",
#             "trde_tern_rt": "+6.66",
#             "trde_amt": "13422",
#             "opmr_trde_qty": "7212442",
#             "opmr_pred_rt": "-28.38",
#             "opmr_trde_rt": "+6.66",
#             "opmr_trde_amt": "13415",
#             "af_mkrt_trde_qty": "3756",
#             "af_mkrt_pred_rt": "-21.93",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "7",
#             "bf_mkrt_trde_qty": "162",
#             "bf_mkrt_pred_rt": "-0.58",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "115480_AL",
#             "stk_nm": "씨유메디칼",
#             "cur_prc": "+617",
#             "pred_pre_sig": "2",
#             "pred_pre": "+22",
#             "flu_rt": "+3.70",
#             "trde_qty": "6773598",
#             "pred_rt": "+22511.13",
#             "trde_tern_rt": "+11.17",
#             "trde_amt": "4504",
#             "opmr_trde_qty": "6773213",
#             "opmr_pred_rt": "+22621.12",
#             "opmr_trde_rt": "+11.18",
#             "opmr_trde_amt": "4503",
#             "af_mkrt_trde_qty": "385",
#             "af_mkrt_pred_rt": "0.00",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "0",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "000970_AL",
#             "stk_nm": "한국주철관",
#             "cur_prc": "+7290",
#             "pred_pre_sig": "2",
#             "pred_pre": "+940",
#             "flu_rt": "+14.80",
#             "trde_qty": "6613193",
#             "pred_rt": "+38999.78",
#             "trde_tern_rt": "+29.00",
#             "trde_amt": "46636",
#             "opmr_trde_qty": "6604673",
#             "opmr_pred_rt": "+41854.71",
#             "opmr_trde_rt": "+28.97",
#             "opmr_trde_amt": "46574",
#             "af_mkrt_trde_qty": "8520",
#             "af_mkrt_pred_rt": "+731.34",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "62",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "013990_AL",
#             "stk_nm": "아가방컴퍼니",
#             "cur_prc": "+7890",
#             "pred_pre_sig": "2",
#             "pred_pre": "+360",
#             "flu_rt": "+4.78",
#             "trde_qty": "6530195",
#             "pred_rt": "+373.80",
#             "trde_tern_rt": "+19.86",
#             "trde_amt": "51491",
#             "opmr_trde_qty": "6528221",
#             "opmr_pred_rt": "+373.81",
#             "opmr_trde_rt": "+19.86",
#             "opmr_trde_amt": "51475",
#             "af_mkrt_trde_qty": "1974",
#             "af_mkrt_pred_rt": "+384.80",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "16",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "403490_AL",
#             "stk_nm": "우듬지팜",
#             "cur_prc": "+1614",
#             "pred_pre_sig": "2",
#             "pred_pre": "+38",
#             "flu_rt": "+2.41",
#             "trde_qty": "6468020",
#             "pred_rt": "+212.72",
#             "trde_tern_rt": "+14.31",
#             "trde_amt": "10667",
#             "opmr_trde_qty": "6467510",
#             "opmr_pred_rt": "+224.12",
#             "opmr_trde_rt": "+14.31",
#             "opmr_trde_amt": "10666",
#             "af_mkrt_trde_qty": "510",
#             "af_mkrt_pred_rt": "-0.64",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "1",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "096250_AL",
#             "stk_nm": "와이즈넛",
#             "cur_prc": "+16220",
#             "pred_pre_sig": "2",
#             "pred_pre": "+1230",
#             "flu_rt": "+8.21",
#             "trde_qty": "6437447",
#             "pred_rt": "+149.65",
#             "trde_tern_rt": "+49.27",
#             "trde_amt": "108601",
#             "opmr_trde_qty": "6431581",
#             "opmr_pred_rt": "+150.42",
#             "opmr_trde_rt": "+49.23",
#             "opmr_trde_amt": "108510",
#             "af_mkrt_trde_qty": "1898",
#             "af_mkrt_pred_rt": "-48.95",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "31",
#             "bf_mkrt_trde_qty": "3968",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.04",
#             "bf_mkrt_trde_amt": "59"
#         },
#         {
#             "stk_cd": "115500_AL",
#             "stk_nm": "케이씨에스",
#             "cur_prc": "+11370",
#             "pred_pre_sig": "2",
#             "pred_pre": "+800",
#             "flu_rt": "+7.57",
#             "trde_qty": "6421940",
#             "pred_rt": "+2663.39",
#             "trde_tern_rt": "+53.52",
#             "trde_amt": "77463",
#             "opmr_trde_qty": "6420014",
#             "opmr_pred_rt": "+2724.97",
#             "opmr_trde_rt": "+53.51",
#             "opmr_trde_amt": "77442",
#             "af_mkrt_trde_qty": "1731",
#             "af_mkrt_pred_rt": "+34620.00",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "20",
#             "bf_mkrt_trde_qty": "195",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "333050_AL",
#             "stk_nm": "모코엠시스",
#             "cur_prc": "-1830",
#             "pred_pre_sig": "5",
#             "pred_pre": "-57",
#             "flu_rt": "-3.02",
#             "trde_qty": "6367728",
#             "pred_rt": "-60.91",
#             "trde_tern_rt": "+25.87",
#             "trde_amt": "11824",
#             "opmr_trde_qty": "6360005",
#             "opmr_pred_rt": "-61.16",
#             "opmr_trde_rt": "+25.84",
#             "opmr_trde_amt": "11810",
#             "af_mkrt_trde_qty": "7723",
#             "af_mkrt_pred_rt": "-28.16",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "14",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "060260_AL",
#             "stk_nm": "뉴보텍",
#             "cur_prc": "+1615",
#             "pred_pre_sig": "1",
#             "pred_pre": "+372",
#             "flu_rt": "+29.93",
#             "trde_qty": "6329334",
#             "pred_rt": "+3185.69",
#             "trde_tern_rt": "+46.84",
#             "trde_amt": "9562",
#             "opmr_trde_qty": "6329334",
#             "opmr_pred_rt": "+3225.01",
#             "opmr_trde_rt": "+46.85",
#             "opmr_trde_amt": "9562",
#             "af_mkrt_trde_qty": "0",
#             "af_mkrt_pred_rt": "+0.00",
#             "af_mkrt_trde_rt": "+0.00",
#             "af_mkrt_trde_amt": "0",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "098070_AL",
#             "stk_nm": "한텍",
#             "cur_prc": "+45200",
#             "pred_pre_sig": "2",
#             "pred_pre": "+300",
#             "flu_rt": "+0.67",
#             "trde_qty": "6284999",
#             "pred_rt": "+172.47",
#             "trde_tern_rt": "+56.51",
#             "trde_amt": "289618",
#             "opmr_trde_qty": "6268812",
#             "opmr_pred_rt": "+180.02",
#             "opmr_trde_rt": "+56.37",
#             "opmr_trde_amt": "288891",
#             "af_mkrt_trde_qty": "1847",
#             "af_mkrt_pred_rt": "-17.16",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "83",
#             "bf_mkrt_trde_qty": "14340",
#             "bf_mkrt_pred_rt": "+95600.00",
#             "bf_mkrt_trde_rt": "+0.13",
#             "bf_mkrt_trde_amt": "644"
#         },
#         {
#             "stk_cd": "034020_AL",
#             "stk_nm": "두산에너빌리티",
#             "cur_prc": "+24150",
#             "pred_pre_sig": "2",
#             "pred_pre": "+800",
#             "flu_rt": "+3.43",
#             "trde_qty": "6163637",
#             "pred_rt": "+118.54",
#             "trde_tern_rt": "+0.96",
#             "trde_amt": "147264",
#             "opmr_trde_qty": "6160065",
#             "opmr_pred_rt": "+118.55",
#             "opmr_trde_rt": "+0.97",
#             "opmr_trde_amt": "147178",
#             "af_mkrt_trde_qty": "3572",
#             "af_mkrt_pred_rt": "+110.94",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "86",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "010140_AL",
#             "stk_nm": "삼성중공업",
#             "cur_prc": "+14550",
#             "pred_pre_sig": "2",
#             "pred_pre": "+100",
#             "flu_rt": "+0.69",
#             "trde_qty": "6126962",
#             "pred_rt": "-62.40",
#             "trde_tern_rt": "+0.70",
#             "trde_amt": "88867",
#             "opmr_trde_qty": "6124017",
#             "opmr_pred_rt": "-62.37",
#             "opmr_trde_rt": "+0.70",
#             "opmr_trde_amt": "88824",
#             "af_mkrt_trde_qty": "1155",
#             "af_mkrt_pred_rt": "-57.20",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "17",
#             "bf_mkrt_trde_qty": "1790",
#             "bf_mkrt_pred_rt": "+179000.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "26"
#         },
#         {
#             "stk_cd": "394800_AL",
#             "stk_nm": "쓰리빌리언",
#             "cur_prc": "+6870",
#             "pred_pre_sig": "2",
#             "pred_pre": "+290",
#             "flu_rt": "+4.41",
#             "trde_qty": "6038651",
#             "pred_rt": "-65.64",
#             "trde_tern_rt": "+19.04",
#             "trde_amt": "41544",
#             "opmr_trde_qty": "6032237",
#             "opmr_pred_rt": "-65.58",
#             "opmr_trde_rt": "+19.02",
#             "opmr_trde_amt": "41501",
#             "af_mkrt_trde_qty": "6023",
#             "af_mkrt_pred_rt": "+258.95",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "41",
#             "bf_mkrt_trde_qty": "391",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "3"
#         },
#         {
#             "stk_cd": "530036_AL",
#             "stk_nm": "삼성 인버스 2X WTI원유 선물 ETN",
#             "cur_prc": "-109",
#             "pred_pre_sig": "5",
#             "pred_pre": "-1",
#             "flu_rt": "-0.91",
#             "trde_qty": "5946755",
#             "pred_rt": "-36.75",
#             "trde_tern_rt": "+0.40",
#             "trde_amt": "648",
#             "opmr_trde_qty": "5946755",
#             "opmr_pred_rt": "-36.77",
#             "opmr_trde_rt": "+0.40",
#             "opmr_trde_amt": "648",
#             "af_mkrt_trde_qty": "0",
#             "af_mkrt_pred_rt": "+0.00",
#             "af_mkrt_trde_rt": "+0.00",
#             "af_mkrt_trde_amt": "0",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "049630_AL",
#             "stk_nm": "재영솔루텍",
#             "cur_prc": "+757",
#             "pred_pre_sig": "2",
#             "pred_pre": "+55",
#             "flu_rt": "+7.83",
#             "trde_qty": "5825068",
#             "pred_rt": "+1194.21",
#             "trde_tern_rt": "+6.60",
#             "trde_amt": "4346",
#             "opmr_trde_qty": "5821884",
#             "opmr_pred_rt": "+1197.86",
#             "opmr_trde_rt": "+6.61",
#             "opmr_trde_amt": "4343",
#             "af_mkrt_trde_qty": "3184",
#             "af_mkrt_pred_rt": "+499.06",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "2",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "069500_AL",
#             "stk_nm": "KODEX 200",
#             "cur_prc": "+33355",
#             "pred_pre_sig": "2",
#             "pred_pre": "+325",
#             "flu_rt": "+0.98",
#             "trde_qty": "5824591",
#             "pred_rt": "+105.70",
#             "trde_tern_rt": "+3.33",
#             "trde_amt": "194149",
#             "opmr_trde_qty": "5810584",
#             "opmr_pred_rt": "+173.60",
#             "opmr_trde_rt": "+3.33",
#             "opmr_trde_amt": "193686",
#             "af_mkrt_trde_qty": "701",
#             "af_mkrt_pred_rt": "-0.03",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "23",
#             "bf_mkrt_trde_qty": "13306",
#             "bf_mkrt_pred_rt": "+33265.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "439"
#         },
#         {
#             "stk_cd": "463480_AL",
#             "stk_nm": "모티브링크",
#             "cur_prc": "+15340",
#             "pred_pre_sig": "2",
#             "pred_pre": "+690",
#             "flu_rt": "+4.71",
#             "trde_qty": "5805821",
#             "pred_rt": "+515.39",
#             "trde_tern_rt": "+46.86",
#             "trde_amt": "93872",
#             "opmr_trde_qty": "5801949",
#             "opmr_pred_rt": "+528.70",
#             "opmr_trde_rt": "+46.83",
#             "opmr_trde_amt": "93813",
#             "af_mkrt_trde_qty": "2637",
#             "af_mkrt_pred_rt": "-94.41",
#             "af_mkrt_trde_rt": "+0.03",
#             "af_mkrt_trde_amt": "40",
#             "bf_mkrt_trde_qty": "1235",
#             "bf_mkrt_pred_rt": "+104.14",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "18"
#         },
#         {
#             "stk_cd": "015750_AL",
#             "stk_nm": "성우하이텍",
#             "cur_prc": "+5480",
#             "pred_pre_sig": "2",
#             "pred_pre": "+430",
#             "flu_rt": "+8.51",
#             "trde_qty": "5762688",
#             "pred_rt": "+1342.12",
#             "trde_tern_rt": "+7.20",
#             "trde_amt": "32646",
#             "opmr_trde_qty": "5762126",
#             "opmr_pred_rt": "+1342.30",
#             "opmr_trde_rt": "+7.21",
#             "opmr_trde_amt": "32643",
#             "af_mkrt_trde_qty": "562",
#             "af_mkrt_pred_rt": "+562.01",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "3",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "020710_AL",
#             "stk_nm": "시공테크",
#             "cur_prc": "-7060",
#             "pred_pre_sig": "5",
#             "pred_pre": "-1000",
#             "flu_rt": "-12.41",
#             "trde_qty": "5718246",
#             "pred_rt": "-38.16",
#             "trde_tern_rt": "+28.52",
#             "trde_amt": "41864",
#             "opmr_trde_qty": "5715330",
#             "opmr_pred_rt": "-38.51",
#             "opmr_trde_rt": "+28.51",
#             "opmr_trde_amt": "41843",
#             "af_mkrt_trde_qty": "2139",
#             "af_mkrt_pred_rt": "-24.07",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "15",
# ...
#             "af_mkrt_pred_rt": "+200.08",
#             "af_mkrt_trde_rt": "+0.06",
#             "af_mkrt_trde_amt": "107",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "052400_AL",
#             "stk_nm": "코나아이",
#             "cur_prc": "-30750",
#             "pred_pre_sig": "5",
#             "pred_pre": "-12200",
#             "flu_rt": "-28.41",
#             "trde_qty": "4493866",
#             "pred_rt": "+602.93",
#             "trde_tern_rt": "+30.86",
#             "trde_amt": "153703",
#             "opmr_trde_qty": "4486780",
#             "opmr_pred_rt": "+615.56",
#             "opmr_trde_rt": "+30.81",
#             "opmr_trde_amt": "153484",
#             "af_mkrt_trde_qty": "6967",
#             "af_mkrt_pred_rt": "+1541.38",
#             "af_mkrt_trde_rt": "+0.05",
#             "af_mkrt_trde_amt": "214",
#             "bf_mkrt_trde_qty": "119",
#             "bf_mkrt_pred_rt": "-36.61",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "5"
#         },
#         {
#             "stk_cd": "027830_AL",
#             "stk_nm": "대성창투",
#             "cur_prc": "-2485",
#             "pred_pre_sig": "5",
#             "pred_pre": "-170",
#             "flu_rt": "-6.40",
#             "trde_qty": "4357692",
#             "pred_rt": "-24.17",
#             "trde_tern_rt": "+8.07",
#             "trde_amt": "11154",
#             "opmr_trde_qty": "4339607",
#             "opmr_pred_rt": "-24.42",
#             "opmr_trde_rt": "+8.04",
#             "opmr_trde_amt": "11109",
#             "af_mkrt_trde_qty": "18081",
#             "af_mkrt_pred_rt": "+104.08",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "45",
#             "bf_mkrt_trde_qty": "4",
#             "bf_mkrt_pred_rt": "-0.02",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "298380_AL",
#             "stk_nm": "에이비엘바이오",
#             "cur_prc": "+64000",
#             "pred_pre_sig": "2",
#             "pred_pre": "+1800",
#             "flu_rt": "+2.89",
#             "trde_qty": "4289951",
#             "pred_rt": "-66.96",
#             "trde_tern_rt": "+8.84",
#             "trde_amt": "272865",
#             "opmr_trde_qty": "4289765",
#             "opmr_pred_rt": "-66.96",
#             "opmr_trde_rt": "+8.84",
#             "opmr_trde_amt": "272853",
#             "af_mkrt_trde_qty": "181",
#             "af_mkrt_pred_rt": "-24.29",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "12",
#             "bf_mkrt_trde_qty": "5",
#             "bf_mkrt_pred_rt": "-9.09",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "229200_AL",
#             "stk_nm": "KODEX 코스닥150",
#             "cur_prc": "-11710",
#             "pred_pre_sig": "5",
#             "pred_pre": "-15",
#             "flu_rt": "-0.13",
#             "trde_qty": "3999919",
#             "pred_rt": "-30.74",
#             "trde_tern_rt": "+3.75",
#             "trde_amt": "46722",
#             "opmr_trde_qty": "3999464",
#             "opmr_pred_rt": "-41.56",
#             "opmr_trde_rt": "+3.76",
#             "opmr_trde_amt": "46717",
#             "af_mkrt_trde_qty": "455",
#             "af_mkrt_pred_rt": "-0.01",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "5",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "032820_AL",
#             "stk_nm": "우리기술",
#             "cur_prc": "+1895",
#             "pred_pre_sig": "2",
#             "pred_pre": "+53",
#             "flu_rt": "+2.88",
#             "trde_qty": "3991316",
#             "pred_rt": "+144.30",
#             "trde_tern_rt": "+2.42",
#             "trde_amt": "7519",
#             "opmr_trde_qty": "3984085",
#             "opmr_pred_rt": "+147.62",
#             "opmr_trde_rt": "+2.42",
#             "opmr_trde_amt": "7505",
#             "af_mkrt_trde_qty": "6231",
#             "af_mkrt_pred_rt": "-53.07",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "12",
#             "bf_mkrt_trde_qty": "1000",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "066910_AL",
#             "stk_nm": "손오공",
#             "cur_prc": "+585",
#             "pred_pre_sig": "2",
#             "pred_pre": "+45",
#             "flu_rt": "+8.33",
#             "trde_qty": "3982209",
#             "pred_rt": "+535.71",
#             "trde_tern_rt": "+7.84",
#             "trde_amt": "2347",
#             "opmr_trde_qty": "3977922",
#             "opmr_pred_rt": "+536.17",
#             "opmr_trde_rt": "+7.84",
#             "opmr_trde_amt": "2345",
#             "af_mkrt_trde_qty": "4287",
#             "af_mkrt_pred_rt": "+4287.00",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "3",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "379800_AL",
#             "stk_nm": "KODEX 미국S&P500",
#             "cur_prc": "-17650",
#             "pred_pre_sig": "5",
#             "pred_pre": "-35",
#             "flu_rt": "-0.20",
#             "trde_qty": "3970820",
#             "pred_rt": "-78.20",
#             "trde_tern_rt": "+1.78",
#             "trde_amt": "69903",
#             "opmr_trde_qty": "3969896",
#             "opmr_pred_rt": "-78.26",
#             "opmr_trde_rt": "+1.78",
#             "opmr_trde_amt": "69887",
#             "af_mkrt_trde_qty": "823",
#             "af_mkrt_pred_rt": "+128.00",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "15",
#             "bf_mkrt_trde_qty": "101",
#             "bf_mkrt_pred_rt": "-6.73",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "007390_AL",
#             "stk_nm": "네이처셀",
#             "cur_prc": "-27450",
#             "pred_pre_sig": "5",
#             "pred_pre": "-3950",
#             "flu_rt": "-12.58",
#             "trde_qty": "3950656",
#             "pred_rt": "+323.77",
#             "trde_tern_rt": "+6.14",
#             "trde_amt": "109752",
#             "opmr_trde_qty": "3949151",
#             "opmr_pred_rt": "+331.01",
#             "opmr_trde_rt": "+6.14",
#             "opmr_trde_amt": "109711",
#             "af_mkrt_trde_qty": "1498",
#             "af_mkrt_pred_rt": "-24.53",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "41",
#             "bf_mkrt_trde_qty": "7",
#             "bf_mkrt_pred_rt": "-0.83",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "452450_AL",
#             "stk_nm": "피아이이",
#             "cur_prc": "+9750",
#             "pred_pre_sig": "2",
#             "pred_pre": "+130",
#             "flu_rt": "+1.35",
#             "trde_qty": "3913638",
#             "pred_rt": "-29.15",
#             "trde_tern_rt": "+10.92",
#             "trde_amt": "38329",
#             "opmr_trde_qty": "3906233",
#             "opmr_pred_rt": "-29.23",
#             "opmr_trde_rt": "+10.91",
#             "opmr_trde_amt": "38258",
#             "af_mkrt_trde_qty": "3107",
#             "af_mkrt_pred_rt": "-38.41",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "30",
#             "bf_mkrt_trde_qty": "4298",
#             "bf_mkrt_pred_rt": "+382.05",
#             "bf_mkrt_trde_rt": "+0.02",
#             "bf_mkrt_trde_amt": "41"
#         },
#         {
#             "stk_cd": "097230_AL",
#             "stk_nm": "HJ중공업",
#             "cur_prc": "-8020",
#             "pred_pre_sig": "5",
#             "pred_pre": "-230",
#             "flu_rt": "-2.79",
#             "trde_qty": "3862749",
#             "pred_rt": "-44.29",
#             "trde_tern_rt": "+4.64",
#             "trde_amt": "30887",
#             "opmr_trde_qty": "3862310",
#             "opmr_pred_rt": "-44.28",
#             "opmr_trde_rt": "+4.64",
#             "opmr_trde_amt": "30883",
#             "af_mkrt_trde_qty": "266",
#             "af_mkrt_pred_rt": "-31.44",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "2",
#             "bf_mkrt_trde_qty": "173",
#             "bf_mkrt_pred_rt": "+167.97",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "1"
#         },
#         {
#             "stk_cd": "069920_AL",
#             "stk_nm": "엑시온그룹",
#             "cur_prc": "+2880",
#             "pred_pre_sig": "2",
#             "pred_pre": "+575",
#             "flu_rt": "+24.95",
#             "trde_qty": "3750785",
#             "pred_rt": "+103.81",
#             "trde_tern_rt": "+10.66",
#             "trde_amt": "9929",
#             "opmr_trde_qty": "3729017",
#             "opmr_pred_rt": "+104.63",
#             "opmr_trde_rt": "+10.60",
#             "opmr_trde_amt": "9866",
#             "af_mkrt_trde_qty": "21768",
#             "af_mkrt_pred_rt": "+161.52",
#             "af_mkrt_trde_rt": "+0.07",
#             "af_mkrt_trde_amt": "63",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "411080_AL",
#             "stk_nm": "샌즈랩",
#             "cur_prc": "+8200",
#             "pred_pre_sig": "2",
#             "pred_pre": "+300",
#             "flu_rt": "+3.80",
#             "trde_qty": "3731164",
#             "pred_rt": "+548.93",
#             "trde_tern_rt": "+24.47",
#             "trde_amt": "31454",
#             "opmr_trde_qty": "3728582",
#             "opmr_pred_rt": "+552.72",
#             "opmr_trde_rt": "+24.46",
#             "opmr_trde_amt": "31433",
#             "af_mkrt_trde_qty": "2582",
#             "af_mkrt_pred_rt": "+138.15",
#             "af_mkrt_trde_rt": "+0.02",
#             "af_mkrt_trde_amt": "21",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "015760_AL",
#             "stk_nm": "한국전력",
#             "cur_prc": "+24100",
#             "pred_pre_sig": "2",
#             "pred_pre": "+550",
#             "flu_rt": "+2.34",
#             "trde_qty": "3594129",
#             "pred_rt": "+186.09",
#             "trde_tern_rt": "+0.56",
#             "trde_amt": "86231",
#             "opmr_trde_qty": "3592161",
#             "opmr_pred_rt": "+186.00",
#             "opmr_trde_rt": "+0.56",
#             "opmr_trde_amt": "86183",
#             "af_mkrt_trde_qty": "1967",
#             "af_mkrt_pred_rt": "+3512.50",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "48",
#             "bf_mkrt_trde_qty": "1",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "042660_AL",
#             "stk_nm": "한화오션",
#             "cur_prc": "-79300",
#             "pred_pre_sig": "5",
#             "pred_pre": "-800",
#             "flu_rt": "-1.00",
#             "trde_qty": "3518154",
#             "pred_rt": "-70.46",
#             "trde_tern_rt": "+1.15",
#             "trde_amt": "278921",
#             "opmr_trde_qty": "3517358",
#             "opmr_pred_rt": "-70.46",
#             "opmr_trde_rt": "+1.15",
#             "opmr_trde_amt": "278858",
#             "af_mkrt_trde_qty": "656",
#             "af_mkrt_pred_rt": "-43.55",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "52",
#             "bf_mkrt_trde_qty": "140",
#             "bf_mkrt_pred_rt": "+14000.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "11"
#         },
#         {
#             "stk_cd": "009190_AL",
#             "stk_nm": "대양금속",
#             "cur_prc": "+1802",
#             "pred_pre_sig": "2",
#             "pred_pre": "+178",
#             "flu_rt": "+10.96",
#             "trde_qty": "3462118",
#             "pred_rt": "+151.92",
#             "trde_tern_rt": "+8.17",
#             "trde_amt": "6248",
#             "opmr_trde_qty": "3458476",
#             "opmr_pred_rt": "+153.48",
#             "opmr_trde_rt": "+8.17",
#             "opmr_trde_amt": "6241",
#             "af_mkrt_trde_qty": "1638",
#             "af_mkrt_pred_rt": "-21.08",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "3",
#             "bf_mkrt_trde_qty": "2004",
#             "bf_mkrt_pred_rt": "0.00",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "3"
#         },
#         {
#             "stk_cd": "039610_AL",
#             "stk_nm": "화성밸브",
#             "cur_prc": "+10700",
#             "pred_pre_sig": "2",
#             "pred_pre": "+390",
#             "flu_rt": "+3.78",
#             "trde_qty": "3461746",
#             "pred_rt": "+399.89",
#             "trde_tern_rt": "+33.25",
#             "trde_amt": "38214",
#             "opmr_trde_qty": "3458983",
#             "opmr_pred_rt": "+480.24",
#             "opmr_trde_rt": "+33.23",
#             "opmr_trde_amt": "38184",
#             "af_mkrt_trde_qty": "2749",
#             "af_mkrt_pred_rt": "-50.72",
#             "af_mkrt_trde_rt": "+0.03",
#             "af_mkrt_trde_amt": "29",
#             "bf_mkrt_trde_qty": "14",
#             "bf_mkrt_pred_rt": "-6.99",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "063440_AL",
#             "stk_nm": "SM Life Design",
#             "cur_prc": "+1531",
#             "pred_pre_sig": "2",
#             "pred_pre": "+42",
#             "flu_rt": "+2.82",
#             "trde_qty": "3433481",
#             "pred_rt": "+331.24",
#             "trde_tern_rt": "+7.46",
#             "trde_amt": "5314",
#             "opmr_trde_qty": "3429651",
#             "opmr_pred_rt": "+344.47",
#             "opmr_trde_rt": "+7.46",
#             "opmr_trde_amt": "5308",
#             "af_mkrt_trde_qty": "3830",
#             "af_mkrt_pred_rt": "-88.14",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "6",
#             "bf_mkrt_trde_qty": "0",
#             "bf_mkrt_pred_rt": "+0.00",
#             "bf_mkrt_trde_rt": "+0.00",
#             "bf_mkrt_trde_amt": "0"
#         },
#         {
#             "stk_cd": "457480_AL",
#             "stk_nm": "ACE 테슬라밸류체인액티브",
#             "cur_prc": "-11825",
#             "pred_pre_sig": "5",
#             "pred_pre": "-260",
#             "flu_rt": "-2.15",
#             "trde_qty": "3349888",
#             "pred_rt": "-67.43",
#             "trde_tern_rt": "+4.47",
#             "trde_amt": "39622",
#             "opmr_trde_qty": "3349678",
#             "opmr_pred_rt": "-67.56",
#             "opmr_trde_rt": "+4.47",
#             "opmr_trde_amt": "39619",
#             "af_mkrt_trde_qty": "10",
#             "af_mkrt_pred_rt": "-7.75",
#             "af_mkrt_trde_rt": "+0.01",
#             "af_mkrt_trde_amt": "0",
#             "bf_mkrt_trde_qty": "200",
#             "bf_mkrt_pred_rt": "-56.81",
#             "bf_mkrt_trde_rt": "+0.01",
#             "bf_mkrt_trde_amt": "2"
#         },
#         {
#             "stk_cd": "163280_AL",
#             "stk_nm": "에어레인",
#             "cur_prc": "-22800",
#             "pred_pre_sig": "5",
#             "pred_pre": "-150",
#             "flu_rt": "-0.65",
#             "trde_qty": "3348647",
#             "pred_rt": "+129.82",
#             "trde_tern_rt": "+40.96",
#             "trde_amt": "75615",
#             "opmr_trde_qty": "3335720",
#             "opmr_pred_rt": "+134.01",
#             "opmr_trde_rt": "+40.81",
#             "opmr_trde_amt": "75319",
#             "af_mkrt_trde_qty": "3216",
#             "af_mkrt_pred_rt": "-36.60",
#             "af_mkrt_trde_rt": "+0.04",
#             "af_mkrt_trde_amt": "73",
#             "bf_mkrt_trde_qty": "9711",
#             "bf_mkrt_pred_rt": "-92.57",
#             "bf_mkrt_trde_rt": "+0.12",
#             "bf_mkrt_trde_amt": "223"
#         }
#     ],
#     "return_code": 0,
#     "return_msg": "정상적으로 처리되었습니다"
# }

# %%
import requests
import json

# 주식분봉차트조회요청
def buy(token, data, cont_yn='N', next_key=''):
	# 1. 요청할 API URL
	host = 'https://mockapi.kiwoom.com' # 모의투자
	# host = 'https://api.kiwoom.com' # 실전투자
	endpoint = '/api/dostk/ordr'
	url =  host + endpoint

	# 2. header 데이터

	headers = {
		'Content-Type': 'application/json;charset=UTF-8',  # 요청 데이터의 형식
		'authorization': f'Bearer {token}',  # 인증 토큰
		'cont-yn': cont_yn,  # 연속조회 여부
		'next-key': next_key,  # 연속조회 키
		'api-id': 'kt10000',  # 요청하는 TR 이름
	}
				
	# 3. http POST 요청
	response = requests.post(url, headers=headers, json=data)

	# 4. 응답 상태 코드와 데이터 출력
	print('Code:', response.status_code)
	print('Header:', json.dumps({key: response.headers.get(key) for key in ['next-key', 'cont-yn', 'api-id']}, indent=4, ensure_ascii=False))
	print('Body:', json.dumps(response.json(), indent=4, ensure_ascii=False))  # JSON 응답을 파싱하여 출력

# 실행 구간
if __name__ == '__main__':
	# 1. 토큰 설정
	MY_ACCESS_TOKEN = 'BFEQZhMt8cgEKVy1Qj2beKI9YMik1wXvfxj0RV8X_TN84hL1kF-r5ZKXovUXSSpM3NK0gkwaTTX_AinxL2E_Bg'# 접근토큰

	# 2. 요청데이터
	params = {
			'dmst_stex_tp': 'KRX',  # 거래소 구분 (예: KRX)
			'stk_cd': '039490',  # 주문할 종목코드 (키움증권)
			'ord_qty': '1',  # 주문 수량
			'ord_uv': '',  # 주문 단가 (시장가 주문은 빈 값)
			'trde_tp': '3',  # 매매 구분 (3: 시장가 주문)
			'cond_uv': '',  # 조건 단가 (해당 사항 없으면 빈 값)
			}

	# 3. API 실행
	buy(token=MY_ACCESS_TOKEN, data=params)
# Out:
# Code: 200
# Header: {
#     "next-key": "",
#     "cont-yn": "N",
#     "api-id": "kt10000"
# }
# Body: {
#     "return_msg": "[2000](RC4058:모의투자 장종료)",
#     "return_code": 20
# }
